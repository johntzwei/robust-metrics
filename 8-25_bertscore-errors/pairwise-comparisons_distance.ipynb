# %%
import pickle
import pandas as pd
import seaborn as sns
import numpy as np
import itertools
import random
from tqdm import tqdm
sns.set()
import matplotlib.pyplot as plt

# %% [markdown]
# # Data

# %%
ra_bleurt = pickle.load(open('../pickles/randomized_approx_bleurt.pkl', 'rb'))
ra_bleurt.head(1)
# Out:
#    year     lp         s1        s2  human_statistic  metric_statistic  \
# 0  2016  cs-en  uedin-nmt  online-B          0.15642          0.139296
#
#    human_c  metric_c  human_sig  metric_sig human_decision metric_decision
# 0        0         0       True        True           gain            gain

# %%
sns.scatterplot(x='human_statistic', y='metric_statistic', data=ra_bleurt)

# %%
ra_bert_score = pickle.load(open('../pickles/randomized_approx_bert_score.pkl', 'rb'))
ra_bert_score.head(1)
# Out:
#    year     lp         s1        s2  human_statistic  metric_statistic  \
# 0  2016  cs-en  uedin-nmt  online-B          0.15642          0.007999
#
#    human_c  metric_c  human_sig  metric_sig human_decision metric_decision
# 0        0         0       True        True           gain            gain

# %%
sns.scatterplot(x='human_statistic', y='metric_statistic', data=ra_bleurt)
